# %% [markdown]
# http://mandel.gart.nz/
#
# https://sciencedemos.org.uk/mandelbrot.php
#
# https://www.mathsisfun.com/numbers/mandelbrot.html
#
# https://en.wikipedia.org/wiki/Mandelbrot_set
#
# https://www.pbs.org/wgbh/nova/physics/fractal-generator.html
#
# https://mandelbrotandco.com/en.index.html
#
# https://retinamandelbrot.com/
#
# https://web.mit.edu/jorloff/www/chaosTalk/mandelbrot/davideckapplets.html
#
# https://fractalfoundation.org/resources/fractal-software/

# %% [markdown]
# https://tsmeets.itch.io/mandelbrot

# %% [markdown]
# https://design.tutsplus.com/tutorials/fractal-art-create-a-3d-julian-fractal-in-apophysis--cms-23669
#
# https://sourceforge.net/directory/
#
# https://sourceforge.net/directory/fractal/
#
# https://en.wikipedia.org/wiki/Apophysis_(software)

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation

x_start, y_start = -2, -2  # an interesting region starts here
width, height = 4, 4  # for 4 units up and right
density_per_unit = 200  # how many pixles per unit

# real and imaginary axis
re = np.linspace(x_start, x_start + width, width * density_per_unit )
im = np.linspace(y_start, y_start + height, height * density_per_unit)


threshold = 20  # max allowed iterations
frames = 100  # number of frames in the animation

# we represent c as c = r*cos(a) + i*r*sin(a) = r*e^{i*a}
r = 0.7885
a = np.linspace(0, 2*np.pi, frames)

fig = plt.figure(figsize=(10, 10))  # instantiate a figure to draw
ax = plt.axes()  # create an axes object

def animate(i):
    ax.clear()  # clear axes object
    ax.set_xticks([], [])  # clear x-axis ticks
    ax.set_yticks([], [])  # clear y-axis ticks
    
    X = np.empty((len(re), len(im)))  # the initial array-like image
    cx, cy = r * np.cos(a[i]), r * np.sin(a[i])  # the initial c number
    
    # iterations for the given threshold
    for i in range(len(re)):
        for j in range(len(im)):
            X[i, j] = julia_quadratic(re[i], im[j], cx, cy, threshold)
    
    img = ax.imshow(X.T, interpolation="bicubic", cmap='magma')
    return [img]

#anim = animation.FuncAnimation(fig, animate, frames=frames, interval=50, blit=True)
#anim.save('julia_set.gif', writer='imagemagick')

# %%
def mandelbrot(x, y, z, max_iter):
    c = complex(x, y, z)
    z = complex(0, 0, 0)
    for i in range(max_iter):
        if abs(z) > 2:
            return i
        z = z * z + c
    return max_iter

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Define the grid boundaries
x_min, x_max = -2, 2
y_min, y_max = -2, 2
z_min, z_max = -2, 2

# Step size for the grid
step = 0.01

# Generate the grid
x = np.arange(x_min, x_max, step)
y = np.arange(y_min, y_max, step)
z = np.arange(z_min, z_max, step)

# Create a meshgrid from the coordinates
X, Y, Z = np.meshgrid(x, y, z)

# Compute the escape time for each point in the grid using the mandelbrot function
escape_time = np.zeros_like(X)
for i in range(X.shape[0]):
    for j in range(X.shape[1]):
        for k in range(X.shape[2]):
            escape_time[i, j, k] = mandelbrot(X[i, j, k], Y[i, j, k], Z[i, j, k], max_iter=100)

# Plot the 3D fractal visualization
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.voxels(X, Y, Z, escape_time)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 26
#      24     for j in range(X.shape[1]):
#      25         for k in range(X.shape[2]):
# ---> 26             escape_time[i, j, k] = mandelbrot(X[i, j, k], Y[i, j, k], Z[i, j, k], max_iter=100)
#      28 # Plot the 3D fractal visualization
#      29 fig = plt.figure()
#
# Cell In[2], line 2, in mandelbrot(x, y, z, max_iter)
#       1 def mandelbrot(x, y, z, max_iter):
# ----> 2     c = complex(x, y, z)
#       3     z = complex(0, 0, 0)
#       4     for i in range(max_iter):
#
# TypeError: complex() takes at most 2 arguments (3 given)

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib.animation import FuncAnimation

# Define the grid and generate the escape time values

# ...

# Create the animation function
def animate(frame):
    ax.view_init(elev=10, azim=frame)

# Generate the animation
animation = FuncAnimation(fig, animate, frames=range(0, 360, 10), interval=100)
plt.show()

# %%
# https://colinchpy.github.io/2023-10-03/17-44-57-753543-creating-3d-fractal-visualizations-and-animations-with-python/

# %%
from fractpy.models import NewtonFractal
model = NewtonFractal("x**8 - 4x**3 + x**2 - 6")
p = model.plot(-2, 2, -2, 2, (1000, 1000))
p

# %%
import turtle
MINIMUM_BRANCH_LENGTH = 5
def build_tree(t, branch_length, shorten_by, angle):
      pass
tree = turtle.Turtle()
tree.hideturtle()
tree.setheading(90)
tree.color('green')
build_tree(tree, 50, 5, 30)
turtle.mainloop()

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mandelbrot(c, z):
    global iterations
    count = 0
    for a in range(iterations):
        z = z**2 + c
        count += 1        
        if(abs(z) > 4):
            break
    return count

# %%
def mandelbrot_set(x, y):
    m = np.zeros((len(x), len(y)))
    for i in range(len(x)):
        for j in range(len(y)):
            c = complex(x[i], y[j])
            z = complex(0, 0)
            count = mandelbrot(c, z)
            m[i, j] = count    
    return m

# %%
# https://elc.github.io/posts/plotting-fractals-step-by-step-with-python/
